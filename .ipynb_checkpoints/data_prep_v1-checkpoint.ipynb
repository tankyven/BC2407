# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
df = pd.read_csv('severeinjury 010115-310118.csv', encoding='unicode_escape')
df_industry = pd.read_csv('2-6 digit_2017_Codes.csv')

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.head()
# Out:
#            ID     UPA EventDate  \
# 0  2015010015  931176  1/1/2015
# 1  2015010016  930267  1/1/2015
# 2  2015010018  929823  1/1/2015
# 3  2015010019  929711  1/1/2015
# 4  2015010020  929642  1/1/2015
#
#                                          Employer               Address1  \
# 0  FCI Otisville Federal Correctional Institution         Two Mile Drive
# 1                      Kalahari Manufacturing LLC     171 Progress Drive
# 2                 Schneider National Bulk Carrier    420 CORAOPOLIS ROAD
# 3                       PEPSI BOTTLING GROUP INC.      4541 HOUSTON AVE.
# 4                 North American Pipe Corporation  210 South Arch Street
#
#   Address2         City         State      Zip  Latitude  \
# 0      NaN    OTISVILLE      NEW YORK  10963.0     41.46
# 1      NaN  LAKE DELTON     WISCONSIN  53940.0     43.59
# 2      NaN   CORAOPOLIS  PENNSYLVANIA  15108.0     40.49
# 3      NaN        MACON       GEORGIA  31206.0     32.77
# 4      NaN   JANESVILLE     WISCONSIN  53545.0     42.67
#
#                          ...                          Nature  \
# 0                        ...                             111
# 1                        ...                            1522
# 2                        ...                              10
# 3                        ...                            1972
# 4                        ...                             111
#
#                                      NatureTitle  Part of Body  \
# 0                                      Fractures           513
# 1             Second degree heat (thermal) burns           519
# 2  Traumatic injuries and disorders, unspecified          9999
# 3       Soreness, pain, hurt-nonspecified injury           510
# 4                                      Fractures          4429
#
#                  Part of Body Title  Event  \
# 0                      Lower leg(s)   1214
# 1                    Leg(s), n.e.c.    317
# 2                   Nonclassifiable   4331
# 3               Leg(s), unspecified    640
# 4  Finger(s), fingernail(s), n.e.c.   6411
#
#                                           EventTitle  Source  \
# 0  Injured by physical contact with person while ...    5721
# 1              Ignition of vapors, gases, or liquids    7261
# 2         Other fall to lower level less than 6 feet    8421
# 3  Caught in or compressed by equipment or object...    8623
# 4  Caught in running equipment or machinery durin...     350
#
#                                          SourceTitle  Secondary Source  \
# 0                                          Co-worker            5772.0
# 1                 Welding, cutting, and blow torches               NaN
# 2                Semi, tractor-trailer, tanker truck             741.0
# 3                                Pallet jack-powered            8420.0
# 4  Metal, woodworking, and special material machi...               NaN
#
#                               Secondary Source Title
# 0                      Inmate or detainee in custody
# 1                                                NaN
# 2                                      Ladders-fixed
# 3  Truck-motorized freight hauling and utility, u...
# 4                                                NaN
#
# [5 rows x 26 columns]

# %%
df.describe()
# Out:
#                  ID           UPA           Zip      Latitude     Longitude  \
# count  3.129800e+04  3.129800e+04  31285.000000  31284.000000  31284.000000
# mean   4.249925e+09  1.122207e+06  47512.908742     36.717400    -87.687979
# std    5.962899e+09  1.067308e+05  25089.683587      5.526223     11.522027
# min    2.015010e+09  8.674120e+05    801.000000    -15.780000   -170.710000
# 25%    2.015108e+09  1.029155e+06  30309.000000     32.130000    -95.500000
# 50%    2.016087e+09  1.121412e+06  45208.000000     38.790000    -87.650000
# 75%    2.017076e+09  1.211848e+06  72315.000000     41.100000    -80.590000
# max    2.017121e+10  1.378179e+06  99901.000000     61.290000    145.760000
#
#        Hospitalized    Amputation    Inspection        Nature  Part of Body  \
# count  31298.000000  31296.000000  1.105000e+04  31298.000000  31298.000000
# mean       0.808103      0.270194  1.161277e+06    872.920314   2223.117931
# std        0.410718      0.449289  7.773772e+04    767.176878   2720.359782
# min        0.000000      0.000000  8.371470e+05      7.000000      6.000000
# 25%        1.000000      0.000000  1.095968e+06    111.000000    320.000000
# 50%        1.000000      0.000000  1.162585e+06   1311.000000    513.000000
# 75%        1.000000      1.000000  1.227324e+06   1311.000000   4422.000000
# max        5.000000      9.000000  1.315854e+06   9999.000000   9999.000000
#
#               Event        Source  Secondary Source
# count  31298.000000  31298.000000       8377.000000
# mean    3908.832002   4818.359224       5159.590665
# std     2511.156788   2908.851445       3238.035044
# min       20.000000     10.000000         10.000000
# 25%      642.000000   3222.000000       2214.000000
# 50%     4331.000000   4152.000000       4418.000000
# 75%     6252.000000   7125.750000       8621.000000
# max     9999.000000   9999.000000       9999.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31298 entries, 0 to 31297
# Data columns (total 26 columns):
# ID                        31298 non-null int64
# UPA                       31298 non-null int64
# EventDate                 31298 non-null object
# Employer                  31298 non-null object
# Address1                  31286 non-null object
# Address2                  2747 non-null object
# City                      31287 non-null object
# State                     31298 non-null object
# Zip                       31285 non-null float64
# Latitude                  31284 non-null float64
# Longitude                 31284 non-null float64
# Primary NAICS             31296 non-null object
# Hospitalized              31298 non-null int64
# Amputation                31296 non-null float64
# Inspection                11050 non-null float64
# Final Narrative           31298 non-null object
# Nature                    31298 non-null int64
# NatureTitle               31297 non-null object
# Part of Body              31298 non-null int64
# Part of Body Title        31298 non-null object
# Event                     31298 non-null int64
# EventTitle                31296 non-null object
# Source                    31298 non-null int64
# SourceTitle               31298 non-null object
# Secondary Source          8377 non-null float64
# Secondary Source Title    8377 non-null object
# dtypes: float64(6), int64(7), object(13)
# memory usage: 6.2+ MB

# %%
df['EventDate'] = pd.to_datetime(df['EventDate'])
df['EventYear'] = df['EventDate'].apply(lambda time: time.year)
df['EventMonth'] = df['EventDate'].apply(lambda time: time.month)
df['EventDay'] = df['EventDate'].apply(lambda time: time.day)
df['EventDayofWeek'] = df['EventDate'].apply(lambda time: time.dayofweek)

# Map numeric output (0-6) to strings
mmap = {1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',
       9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
dmap = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
df['EventDayofWeek'] = df['EventDayofWeek'].map(dmap)
df['EventMonth'] = df['EventMonth'].map(mmap)

# %% [markdown]
# Added a few features form the EventDate column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31298 entries, 0 to 31297
# Data columns (total 30 columns):
# ID                        31298 non-null int64
# UPA                       31298 non-null int64
# EventDate                 31298 non-null datetime64[ns]
# Employer                  31298 non-null object
# Address1                  31286 non-null object
# Address2                  2747 non-null object
# City                      31287 non-null object
# State                     31298 non-null object
# Zip                       31285 non-null float64
# Latitude                  31284 non-null float64
# Longitude                 31284 non-null float64
# Primary NAICS             31296 non-null object
# Hospitalized              31298 non-null int64
# Amputation                31296 non-null float64
# Inspection                11050 non-null float64
# Final Narrative           31298 non-null object
# Nature                    31298 non-null int64
# NatureTitle               31297 non-null object
# Part of Body              31298 non-null int64
# Part of Body Title        31298 non-null object
# Event                     31298 non-null int64
# EventTitle                31296 non-null object
# Source                    31298 non-null int64
# SourceTitle               31298 non-null object
# Secondary Source          8377 non-null float64
# Secondary Source Title    8377 non-null object
# EventYear                 31298 non-null int64
# EventMonth                31298 non-null object
# EventDay                  31298 non-null int64
# EventDayofWeek            31298 non-null object
# dtypes: datetime64[ns](1), float64(6), int64(9), object(14)
# memory usage: 7.2+ MB

# %%
# sns.pairplot(df, palette='viridis')

# %%
sns.countplot(x='EventYear', data = df, palette='viridis')
plt.title('Number of Accidents in a Year')
# Out:
# Text(0.5, 1.0, 'Number of Accidents in a Year')

# %% [markdown]
# Number of accidents seems to have risen year by year from 2015 to 2017. Furthermore, only a few data points occurred in 2018.

# %%
sns.countplot(x='EventMonth', data = df, palette='viridis')
plt.title('Number of Accidents in each Month')
# Out:
# Text(0.5, 1.0, 'Number of Accidents in each Month')

# %% [markdown]
# January, July and August seem to be the most accident-prone months of the year.

# %%
sns.countplot(x='EventDayofWeek', data = df, palette='viridis')
plt.title('Number of Accidents in a week')
# Out:
# Text(0.5, 1.0, 'Number of Accidents in a week')

# %% [markdown]
# Accidents tend to peak mid week and then reduce over the weekends, which makes sense as the number of people working falls during the weekends.

# %%
df['Corrected_State'] = df['State'].str.lower().str.title()
df_plot = df.groupby(by='Corrected_State').count()
df_plot = df_plot.reset_index()

us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}
df_plot['State_Abrv'] = df_plot['Corrected_State'].map(us_state_abbrev)
df_plot.sort_values(by='ID', ascending=False)
# Remove NAs
df_plot = df_plot.dropna()

# %%
for col in df_plot.columns:
    df_plot[col] = df_plot[col].astype(str)

# scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
#             [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]

df_plot['text'] = df_plot['Corrected_State']+'<br>'+'Number of Accidents: '+df_plot['ID']
colorscale = ["#f7fbff", "#ebf3fb", "#deebf7", "#d2e3f3", "#c6dbef",
                  "#b3d2e9", "#9ecae1", "#85bcdb", "#6baed6", "#57a0ce",
                  "#4292c6", "#3082be", "#2171b5", "#1361a9", "#08519c",
                  "#0b4083","#08306b"]
data = [dict(
        type='choropleth',
        autocolorscale = True,
        locations = df_plot['State_Abrv'],
        z = df_plot['ID'].astype(float),
        locationmode = 'USA-states',
        text = df_plot['text'],
        marker = dict(
            line = dict(
                color = 'rgb(255,255,255)',
                width = 2
            )
        ),
        colorbar = dict(
            title = "No. of Accidents")
) ]

layout = dict(
    title = 'Accidents per State from 2016-2018',
    geo = dict(
        scope='usa',
        projection=dict( type='albers usa' ),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)'
    )
)

fig = dict(data=data, layout=layout)

url = iplot(fig, filename='choropleth_map')
# Out:
# <div id="32b7f0c0-5999-43bb-afba-00e9198dba5a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("32b7f0c0-5999-43bb-afba-00e9198dba5a", [{"autocolorscale": true, "colorbar": {"title": {"text": "No. of Accidents"}}, "locationmode": "USA-states", "locations": ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"], "marker": {"line": {"color": "rgb(255,255,255)", "width": 2}}, "text": ["Alabama<br>Number of Accidents: 957", "Alaska<br>Number of Accidents: 7", "Arizona<br>Number of Accidents: 41", "Arkansas<br>Number of Accidents: 704", "California<br>Number of Accidents: 160", "Colorado<br>Number of Accidents: 969", "Connecticut<br>Number of Accidents: 323", "Delaware<br>Number of Accidents: 131", "Florida<br>Number of Accidents: 3176", "Georgia<br>Number of Accidents: 1692", "Hawaii<br>Number of Accidents: 25", "Idaho<br>Number of Accidents: 309", "Illinois<br>Number of Accidents: 1938", "Indiana<br>Number of Accidents: 17", "Iowa<br>Number of Accidents: 9", "Kansas<br>Number of Accidents: 639", "Kentucky<br>Number of Accidents: 30", "Louisiana<br>Number of Accidents: 780", "Maine<br>Number of Accidents: 235", "Maryland<br>Number of Accidents: 44", "Massachusetts<br>Number of Accidents: 753", "Michigan<br>Number of Accidents: 29", "Minnesota<br>Number of Accidents: 22", "Mississippi<br>Number of Accidents: 641", "Missouri<br>Number of Accidents: 942", "Montana<br>Number of Accidents: 154", "Nebraska<br>Number of Accidents: 505", "Nevada<br>Number of Accidents: 3", "New Hampshire<br>Number of Accidents: 163", "New Jersey<br>Number of Accidents: 776", "New Mexico<br>Number of Accidents: 28", "New York<br>Number of Accidents: 1568", "North Carolina<br>Number of Accidents: 39", "North Dakota<br>Number of Accidents: 331", "Ohio<br>Number of Accidents: 2425", "Oklahoma<br>Number of Accidents: 658", "Oregon<br>Number of Accidents: 34", "Pennsylvania<br>Number of Accidents: 2504", "Rhode Island<br>Number of Accidents: 108", "South Carolina<br>Number of Accidents: 31", "South Dakota<br>Number of Accidents: 212", "Tennessee<br>Number of Accidents: 43", "Texas<br>Number of Accidents: 5143", "Utah<br>Number of Accidents: 26", "Vermont<br>Number of Accidents: 3", "Virginia<br>Number of Accidents: 127", "Washington<br>Number of Accidents: 54", "West Virginia<br>Number of Accidents: 303", "Wisconsin<br>Number of Accidents: 1343", "Wyoming<br>Number of Accidents: 10"], "z": [957.0, 7.0, 41.0, 704.0, 160.0, 969.0, 323.0, 131.0, 3176.0, 1692.0, 25.0, 309.0, 1938.0, 17.0, 9.0, 639.0, 30.0, 780.0, 235.0, 44.0, 753.0, 29.0, 22.0, 641.0, 942.0, 154.0, 505.0, 3.0, 163.0, 776.0, 28.0, 1568.0, 39.0, 331.0, 2425.0, 658.0, 34.0, 2504.0, 108.0, 31.0, 212.0, 43.0, 5143.0, 26.0, 3.0, 127.0, 54.0, 303.0, 1343.0, 10.0], "type": "choropleth", "uid": "2cdfa3d8-bde4-436f-a513-4f9902f4d193"}], {"geo": {"lakecolor": "rgb(255, 255, 255)", "projection": {"type": "albers usa"}, "scope": "usa", "showlakes": true}, "title": {"text": "Accidents per State from 2016-2018"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("32b7f0c0-5999-43bb-afba-00e9198dba5a"));});</script>

# %% [markdown]
# We can see that most of the accidents are concentrated in the central to east states. This suggests that we can look into the safety policies in the western states and compare them with safety policies in the central to east states to see if there are any significant differences that account for the differing accident rates.

# %%
# Group and count rows in each NatureTitle
df_NatureTitle = df.groupby(by='NatureTitle').count().sort_values(by='Nature', ascending=False).reset_index()

ax = sns.barplot(x='NatureTitle', y='ID', data=df_NatureTitle.head(10), palette='viridis')
plt.title('Top 10 Nature of Accidents')
ax.set_ylabel('Count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
# Out:
# [Text(0, 0, 'Fractures'),
#  Text(0, 0, 'Amputations'),
#  Text(0, 0, 'Soreness, pain, hurt-nonspecified injury'),
#  Text(0, 0, 'Cuts, lacerations'),
#  Text(0, 0, 'Traumatic injuries and disorders, unspecified'),
#  Text(0, 0, 'Intracranial injuries, unspecified'),
#  Text(0, 0, 'Crushing injuries'),
#  Text(0, 0, 'Heat (thermal) burns, unspecified'),
#  Text(0, 0, 'Puncture wounds, except gunshot wounds'),
#  Text(0, 0, 'Internal injuries to organs and blood vessels of the trunk')]

# %% [markdown]
# This shows the most common types of accidents are fractures and amputations.

# %%
# Group and count rows in each Part of Body Title
df_NatureTitle = df.groupby(by='Part of Body Title').count().sort_values(by='Part of Body', ascending=False).reset_index()

ax = sns.barplot(x='Part of Body Title', y='ID', data=df_NatureTitle.head(10), palette='viridis')
plt.title('Top 10 Body Parts Affected')
ax.set_ylabel('Count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
# Out:
# [Text(0, 0, 'Finger(s), fingernail(s), n.e.c.'),
#  Text(0, 0, 'Fingertip(s)'),
#  Text(0, 0, 'Finger(s), fingernail(s), unspecified'),
#  Text(0, 0, 'Nonclassifiable'),
#  Text(0, 0, 'Multiple body parts, n.e.c.'),
#  Text(0, 0, 'BODY SYSTEMS'),
#  Text(0, 0, 'Leg(s), unspecified'),
#  Text(0, 0, 'Hip(s)'),
#  Text(0, 0, 'Brain'),
#  Text(0, 0, 'Ankle(s)')]

# %% [markdown]
# Fingers are the most common injured body part.

# %%
# Group and count rows in each Event Title
df_NatureTitle = df.groupby(by='EventTitle').count().sort_values(by='Event', ascending=False).reset_index()

ax = sns.barplot(x='EventTitle', y='ID', data=df_NatureTitle.head(10), palette='viridis')
plt.title('Top 10 Events')
ax.set_ylabel('Count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
# Out:
# [Text(0, 0, 'Caught in running equipment or machinery during regular operation'),
#  Text(0, 0, 'Compressed or pinched by shifting objects or equipment'),
#  Text(0, 0, 'Caught in running equipment or machinery during maintenance, cleaning '),
#  Text(0, 0, 'Other fall to lower level, unspecified'),
#  Text(0, 0, 'Fall on same level due to slipping '),
#  Text(0, 0, 'Other fall to lower level less than 6 feet'),
#  Text(0, 0, 'Struck against moving part of machinery or equipment'),
#  Text(0, 0, 'Fall on same level due to tripping over an object '),
#  Text(0, 0, 'Exposure to environmental heat'),
#  Text(0, 0, 'Struck by falling object or equipment, n.e.c.')]

# %% [markdown]
# Most of the accidents occurred during the use of equipment. This might suggest operational safety guidelines are not sufficient.

# %%
# Group and count rows in each Source Title
df_NatureTitle = df.groupby(by='SourceTitle').count().sort_values(by='Source', ascending=False).reset_index()

ax = sns.barplot(x='SourceTitle', y='ID', data=df_NatureTitle.head(10), palette='viridis')
plt.title('Top 10 Sources of Accidents')
ax.set_ylabel('Count')
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right")
# Out:
# [Text(0, 0, 'Floor, n.e.c.'),
#  Text(0, 0, 'Forklift, order picker, platform truck-powered'),
#  Text(0, 0, 'Nonclassifiable'),
#  Text(0, 0, 'Heat-environmental'),
#  Text(0, 0, 'Floors, walkways, ground surfaces, unspecified'),
#  Text(0, 0, 'Ladders, unspecified'),
#  Text(0, 0, 'Movable ladders, unspecified'),
#  Text(0, 0, 'Step ladders'),
#  Text(0, 0, 'Machinery, unspecified'),
#  Text(0, 0, 'Highway vehicle, motorized, unspecified')]

# %%
df['Employer'].value_counts()
# Out:
# U.S. Postal Service                              168
# UPS                                               75
# United States Postal Service                      73
# U.S. POSTAL SERVICE                               73
# USPS                                              51
# US Postal Service                                 43
# United Parcel Service                             39
# Walmart                                           31
# Tyson Foods, Inc.                                 24
# DHL Supply Chain                                  22
# Waste Management                                  22
# Publix                                            20
# Lowe's Home Centers, LLC                          18
# Basic Energy Services                             18
# Publix Super Markets, Inc.                        18
# United Parcel Service, Inc.                       18
# AT&T                                              17
# Sodexo                                            17
# Halliburton Energy Services                       17
# Kroger                                            16
# XPO Logistics                                     15
# Asplundh Tree Expert Company                      15
# American Airlines                                 15
# Menard, Inc.                                      15
# AMERICAN AIRLINES                                 14
# Charter Communications                            14
# Smithfield Foods                                  14
# Labor Ready                                       14
# International Paper                               14
# International Paper Company                       13
#                                                 ...
# Blount Hauling and Landfill                        1
# Lehigh Technologies, Inc.                          1
# Sandbox Logistics, LLC                             1
# Construct Corps, LLC                               1
# Documation, LLC                                    1
# RRI Aurora, Inc.                                   1
# Sub-Zero, Inc.                                     1
# CORPORATE CONSTRUCTION LTD.                        1
# Flexjet LLC                                        1
# DAKOTA PROVISIONS                                  1
# DP South Texas Plumbing Co Inc.                    1
# Design Build Construction Inc.                     1
# Cooper Power Systems, LLC                          1
# Motley-Motley Inc.                                 1
# Arcadia Health and Rehabilitation Center           1
# Milacron Marketing Company LLC                     1
# MID-WEST FORGE CORPORATION                         1
# Tailored Brands dba The Men's Wearhouse, Inc.      1
# Red Cedar Steel Erectors, Inc.                     1
# Vincent De Santis & Michael Heath                  1
# Leslie's Poolmart, Inc.                            1
# G.W. Lisk                                          1
# AMTEC Corporation                                  1
# Aluminum Extrusions, Inc.                          1
# Cassens Transport Co.                              1
# McBride and Son Contracting Co.                    1
# McGraw Webb Chevrolet, Inc.                        1
# Estes Oil Burner Service Inc.                      1
# Ike's Roofing & Construction, Inc.                 1
# Bath and Body Works                                1
# Name: Employer, Length: 25261, dtype: int64

# %% [markdown]
# From this we can see that most of the accidents occured in the postal industry and hence, we could focus on that industry to come up with more targeted insights.

# %%
df['Primary NAICS'].head(5)
# Out:
# 0    922140
# 1    339999
# 2    484121
# 3    424490
# 4    326122
# Name: Primary NAICS, dtype: object

# %%
df['Industry'] = df['Primary NAICS'].apply(lambda x: str(x)[:2])

# %%
# Merge with industry title csv
df_industry = df_industry[['NAICS_Code','NAICS_Title']]
df_industry = df_industry[:17]

# Add merging code here
# Out:
#     NAICS_Code                                        NAICS_Title
# 0         11.0         Agriculture, Forestry, Fishing and Hunting
# 1         21.0      Mining, Quarrying, and Oil and Gas Extraction
# 2         22.0                                          Utilities
# 3         23.0                                       Construction
# 4         42.0                                    Wholesale Trade
# 5         51.0                                        Information
# 6         52.0                              Finance and Insurance
# 7         53.0                 Real Estate and Rental and Leasing
# 8         54.0   Professional, Scientific, and Technical Services
# 9         55.0            Management of Companies and Enterprises
# 10        56.0  Administrative and Support and Waste Managemen...
# 11        61.0                               Educational Services
# 12        62.0                  Health Care and Social Assistance
# 13        71.0                Arts, Entertainment, and Recreation
# 14        72.0                    Accommodation and Food Services
# 15        81.0      Other Services (except Public Administration)
# 16        92.0                              Public Administration

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Handling Missing Values

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), yticklabels=False)

# %% [markdown]
# We can see that the missing values are concentrated in 4 columns: Address2, Inspection, Secondary Source and Secondary Source Title.
#
# Hence, we will aim to preserve Address2 & Secondary Source by modifying them into binary options.

# %%
print('Number of missing values in Address2: ', df['Address2'].isnull().sum())
print('Number of missing values in Inspection: ', df['Inspection'].isnull().sum())
print('Number of missing values in Secondary Source: ', df['Secondary Source'].isnull().sum())
print('Number of missing values in Secondary Source Title: ', df['Secondary Source Title'].isnull().sum())
# Out:
# Number of missing values in Address2:  28551
# Number of missing values in Inspection:  20248
# Number of missing values in Secondary Source:  22921
# Number of missing values in Secondary Source Title:  22921

# %%
df['Have_Address2'] = df['Address2'].notnull().astype('int')
df['Have_SecondarySource'] = df['Secondary Source'].notnull().astype('int')
df = df.drop(labels=['Address2', 'Secondary Source', 'Secondary Source Title'], axis=1)

# %% [markdown]
# Insufficient contextual information is given for the Inspection column. Hence, we've have chosen to drop it for now.

# %%
df = df.drop(labels=['Inspection', 'Corrected_State'], axis=1)

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), yticklabels=False)

# %% [markdown]
# ### Handling Outliers

# %%
df['Hospitalized'].value_counts()
# Out:
# 1    24893
# 0     6209
# 2      191
# 3        4
# 5        1
# Name: Hospitalized, dtype: int64

# %%
df['Amputation'].value_counts()
# Out:
# 0.0    22879
# 1.0     8390
# 2.0       22
# 3.0        3
# 9.0        1
# 4.0        1
# Name: Amputation, dtype: int64

# %% [markdown]
# Based on the results, we are going to assume that these 2 columns were meant for only contain binary results and that the inputs apart from 0 & 1 are errors.

# %%
print('% of errors in {}: {:.2f}%'.format('Hospitalized', len(df[df['Hospitalized'] > 1])/len(df)*100))
print('% of errors in {}: {:.2f}%'.format('Amputation', len(df[df['Amputation'] > 1])/len(df)*100))
# Out:
# % of errors in Hospitalized: 0.63%
# % of errors in Amputation: 0.09%

# %% [markdown]
# As the number of rows with erroneous data are low, we will drop these rows.

# %%
df = df[df['Hospitalized']<2]
df = df[df['Amputation']<2]

# %%
len(df)
# Out:
# 31076

# %% [markdown]
# ### Remove unnecessary columns

# %%
df.drop(['ID', 'UPA', 'Address1', 'Zip', 'Latitude', 
         'Longitude', 'EventDate', 'Event', 'Source',
        'Part of Body', 'Nature','Primary NAICS'], axis = 1, inplace = True)

# %%
df
# Out:
#                                              Employer              City  \
# 0      FCI Otisville Federal Correctional Institution         OTISVILLE
# 1                          Kalahari Manufacturing LLC       LAKE DELTON
# 2                     Schneider National Bulk Carrier        CORAOPOLIS
# 3                           PEPSI BOTTLING GROUP INC.             MACON
# 4                     North American Pipe Corporation        JANESVILLE
# 5                                The Home Depot, Inc.        CAPE CORAL
# 6                                     Gopher Resource             TAMPA
# 7                               Foster Trucking, Inc.              GILL
# 8                                   Trinidad Drilling          WOODWARD
# 9                                 The Krystal Company           ORLANDO
# 10                             US Ecology Texas, Inc.          ROBSTOWN
# 11                             Flowers Baking Company             MIAMI
# 12                               Walmart Stores, Inc.            IRVING
# 13                        KEYSTONE CONCRETE PLACEMENT         GALVESTON
# 14                               KELLY SERVICES, INC.            MONROE
# 15                             House of Raeford Farms           ARCADIA
# 16                                          Circle K        SPRING HILL
# 17                               Clarion Boards, Inc.      SHIPPENVILLE
# 18                                  BROCHSTEINS, INC.            DALLAS
# 19                           DYNAMIC INDUSTRIES, INC.           CAMERON
# 20                           True Temper Sports, Inc.             AMORY
# 21                                           PNC Bank     WOODLAND PARK
# 22                        Insteel Wire Products, Inc.            DAYTON
# 23                         Northstar Contracting Inc.         CLEVELAND
# 24                       Costco Wholesale Corporation        SCHAUMBURG
# 25                           Dal Global Services, LLC             TAMPA
# 26                                        Cablevision            EDISON
# 27            Packers Sanitation Services, Inc., LTD.             OMAHA
# 28                           Tropicana Products, Inc.         BRADENTON
# 29      Crotched Mountain Rehabilitation Center, Inc.        GREENFIELD
# ...                                               ...               ...
# 31268                         Total Equipment Company        CORAOPOLIS
# 31269                         Integrity Services, LLC           MIDLAND
# 31270                          United Parcel Services       KANSAS CITY
# 31271                                         Walmart         NEW ROADS
# 31272                Carpenter Technology Corporation           READING
# 31273              Giant Eagle/American Seaway Foods            BEDFORD
# 31274                             Cache Trucking, LLC      WATFORD CITY
# 31275                        IP Casino Resort and Spa            BILOXI
# 31276  Green Thumb Environmental Beautification, Inc.            CANTON
# 31277                  Northern Engraving Corporation            SPARTA
# 31278                              Fey Publishing Co.  WISCONSIN RAPIDS
# 31279                          B & J Hot Oil Services           GREELEY
# 31280                                  Bush Hog, Inc.             SELMA
# 31281                          Kaiser Aluminum Alexco          CHANDLER
# 31282          Walt Disney Parks and Resorts US, Inc.  LAKE BUENA VISTA
# 31283                   United Parcel Service, Inc.            HODGKINS
# 31284              Finger Lakes Refuse & Disposal Inc       CANANDAIGUA
# 31285                   Crazy Aaron Enterprises, Inc.        NORRISTOWN
# 31286                Chiaramonte Construction Company        WASHINGTON
# 31287                BEMIS CO., INC., SPECIALTY FILMS           OSHKOSH
# 31288                       Motorcars of Lincoln, LLC           LINCOLN
# 31289         NICKS' LANDSCAPING & TREE SERVICE, INC.        NORTHFIELD
# 31290                         Lowe's Home Centers LLC        CLARKSBURG
# 31291             Florida's Frame Pro Carpentry, Inc.     FLAGLER BEACH
# 31292                      Palletone of Florida, Inc.        HAZLEHURST
# 31293                             U.S. Postal Service           CLOSTER
# 31294                                      Hutco, Inc             HOUMA
# 31295                                   DSC LOGISTICS           ATLANTA
# 31296            MOUNTAIN VALLEY SPRING COMPANY, LLC.       HOT SPRINGS
# 31297                             APCO Petroleum Inc.        BURLINGTON
#
#                       State Primary NAICS  Hospitalized  Amputation  \
# 0                  NEW YORK        922140             1         0.0
# 1                 WISCONSIN        339999             1         0.0
# 2              PENNSYLVANIA        484121             1         0.0
# 3                   GEORGIA        424490             1         0.0
# 4                 WISCONSIN        326122             1         0.0
# 5                   FLORIDA        444110             1         0.0
# 6                   FLORIDA        331492             0         1.0
# 7                  COLORADO        213112             1         0.0
# 8                  OKLAHOMA        213111             1         0.0
# 9                   FLORIDA        722211             0         1.0
# 10                    TEXAS        562211             1         0.0
# 11                  FLORIDA        311811             1         0.0
# 12                    TEXAS        452112             1         0.0
# 13                    TEXAS        238110             1         0.0
# 14                WISCONSIN        561320             0         1.0
# 15                LOUISIANA        311615             0         1.0
# 16                  FLORIDA        447110             1         0.0
# 17             PENNSYLVANIA        321219             0         1.0
# 18                    TEXAS        321918             0         1.0
# 19                LOUISIANA        237990             1         0.0
# 20              MISSISSIPPI        331210             1         0.0
# 21               NEW JERSEY        521110             1         0.0
# 22                    TEXAS        331222             1         1.0
# 23                     OHIO        238990             1         0.0
# 24                 ILLINOIS        445110             1         0.0
# 25                  FLORIDA        488119             0         1.0
# 26               NEW JERSEY        515210             1         0.0
# 27                 NEBRASKA        561720             1         0.0
# 28                  FLORIDA        311411             1         0.0
# 29            NEW HAMPSHIRE        623210             1         0.0
# ...                     ...           ...           ...         ...
# 31268          PENNSYLVANIA        332710             1         0.0
# 31269                 TEXAS        213111             1         0.0
# 31270                KANSAS        492110             1         0.0
# 31271             LOUISIANA        452111             1         0.0
# 31272          PENNSYLVANIA        331111             1         0.0
# 31273                  OHIO        452910             1         0.0
# 31274          NORTH DAKOTA        213112             1         0.0
# 31275           MISSISSIPPI        721120             1         0.0
# 31276              NEW YORK        561320             1         0.0
# 31277             WISCONSIN        332999             1         0.0
# 31278             WISCONSIN        323110             1         0.0
# 31279              COLORADO        213112             1         0.0
# 31280               ALABAMA        333111             1         0.0
# 31281               ARIZONA        331316             0         1.0
# 31282               FLORIDA        713110             1         0.0
# 31283              ILLINOIS        492110             1         0.0
# 31284              NEW YORK        562111             0         1.0
# 31285          PENNSYLVANIA        326299             1         0.0
# 31286  DISTRICT OF COLUMBIA        236220             1         1.0
# 31287             WISCONSIN        326112             0         1.0
# 31288              NEBRASKA        441110             1         0.0
# 31289                  OHIO        561730             1         1.0
# 31290         WEST VIRGINIA        444110             1         0.0
# 31291               FLORIDA        238130             1         0.0
# 31292               GEORGIA        321920             0         1.0
# 31293            NEW JERSEY        491110             1         0.0
# 31294             LOUISIANA        561320             1         0.0
# 31295               GEORGIA        236220             1         0.0
# 31296              ARKANSAS        445299             0         1.0
# 31297            NEW JERSEY        447190             1         0.0
#
#                                          Final Narrative  \
# 0      Three correctional facility guards were escort...
# 1      Employee in the Machine Shop received second d...
# 2      A truck driver fell approximately 4 feet while...
# 3      An employee's leg was pinned between a truck a...
# 4      An employee working on the Line 6 Auto-Beller ...
# 5      An employee was hospitalized after slipping an...
# 6      Employee working the flipping machine at the c...
# 7      Employee sustained burns during line tie-in op...
# 8      One employee was hospitalized after being stru...
# 9      An associate was using a knife to open a bag o...
# 10     An employee was struck by an excavator on 01/0...
# 11     On or about 1/2/15 at 9:10 p.m., an employee w...
# 12     An employee stumbled and fell to the ground on...
# 13     Two employees in a scissor lift were wrecking ...
# 14     Employee amputated tip of finger when his fing...
# 15     An employee suffered a right index finger ampu...
# 16     An employee was injured by a customer's automo...
# 17     Employee suffered the amputation of three fing...
# 18     An employee who was using a cordless circular ...
# 19     On Friday, January 2, 2015, at 10:30 p.m., a c...
# 20     The employee was coming down a ladder after pl...
# 21     Employee tripped on a paver and fractured her ...
# 22     Employees use a draw machine to extrude wire. ...
# 23     While in the process of unloading pre-tied mat...
# 24     Employee lost his nail, skin, and flesh from t...
# 25     An employee suffered a trans-phalangeal amputa...
# 26     Employee was installing a new cable on a home ...
# 27     Worker caught a hand in a running conveyor whi...
# 28     An employee was hospitalized after being hit b...
# 29     An employee was assaulted by a patient (chokin...
# ...                                                  ...
# 31268  An employee was operating a boring machine. He...
# 31269  An employee was tripping pipe (drilling the pi...
# 31270  An employee was assaulted by another employee ...
# 31271  An employee's ankle was pinned between a palle...
# 31272  On January 31, 2018, an employee was processin...
# 31273  An employee was being trained on a powered ind...
# 31274  An employee was in a harness and was raised in...
# 31275  An employee was cooking with a tilt skillet th...
# 31276  An employee fell backward and struck the back ...
# 31277  While walking through a door opening, an emplo...
# 31278  An employee slipped and fell on ice in the par...
# 31279  An employee was trying to light a burn box, bu...
# 31280  An employee was operating a shot blaster to cl...
# 31281  An employee was operating a 90-ton saw to cut ...
# 31282  An employee was retrieving a product from a pa...
# 31283  An employee was climbing down a ladder when he...
# 31284  An employee helped a driver reconnect a dumpst...
# 31285  An employee was cleaning a mixer with a can of...
# 31286  An employee was attempting to lift a bundle of...
# 31287  An employee was kneeling on the floor and rais...
# 31288  A maintenance employee was using a scissor lif...
# 31289  An employee was greasing the bearing on a wood...
# 31290  On January 30, 2018, at approximately 11:30 a....
# 31291  On January 31, 2018, at 11:30 a.m., an employe...
# 31292  An employee was trying to clear a jam on a six...
# 31293  An employee was delivering mail when he slippe...
# 31294  An employee became ill while cleaning with a g...
# 31295  An employee was operating a pallet jack. When ...
# 31296  An employee was working on the multi-gallon co...
# 31297  An employee was putting garbage into the dumps...
#
#                                              NatureTitle  \
# 0                                              Fractures
# 1                     Second degree heat (thermal) burns
# 2          Traumatic injuries and disorders, unspecified
# 3               Soreness, pain, hurt-nonspecified injury
# 4                                              Fractures
# 5               Soreness, pain, hurt-nonspecified injury
# 6                                            Amputations
# 7                      Heat (thermal) burns, unspecified
# 8          Traumatic injuries and disorders, unspecified
# 9                                            Amputations
# 10                                             Fractures
# 11                       Electrocutions, electric shocks
# 12                                             Fractures
# 13                                             Fractures
# 14                                           Amputations
# 15                                           Amputations
# 16         Traumatic injuries and disorders, unspecified
# 17                                           Amputations
# 18                                           Amputations
# 19                Puncture wounds, except gunshot wounds
# 20                                             Fractures
# 21                                             Fractures
# 22                                           Amputations
# 23                                             Fractures
# 24                               Avulsions, enucleations
# 25                                           Amputations
# 26              Soreness, pain, hurt-nonspecified injury
# 27                                             Fractures
# 28                                             Fractures
# 29           Asphyxiations, strangulations, suffocations
# ...                                                  ...
# 31268                                          Fractures
# 31269  Internal injuries to organs and blood vessels ...
# 31270                                          Fractures
# 31271                                          Fractures
# 31272                                          Fractures
# 31273                                          Fractures
# 31274           Soreness, pain, hurt-nonspecified injury
# 31275                  Heat (thermal) burns, unspecified
# 31276        Cerebral and other intracranial hemorrhages
# 31277                                          Fractures
# 31278           Soreness, pain, hurt-nonspecified injury
# 31279                 Second degree heat (thermal) burns
# 31280                                          Fractures
# 31281                                        Amputations
# 31282                                          Fractures
# 31283      Traumatic injuries and disorders, unspecified
# 31284                                        Amputations
# 31285                  Heat (thermal) burns, unspecified
# 31286                                  Crushing injuries
# 31287                                        Amputations
# 31288                                          Fractures
# 31289                                        Amputations
# 31290        Cerebral and other intracranial hemorrhages
# 31291  Multiple traumatic injuries and disorders, n.e.c.
# 31292                                        Amputations
# 31293                                  Cuts, lacerations
# 31294                 Hernias due to traumatic incidents
# 31295                                  Cuts, lacerations
# 31296                                        Amputations
# 31297                 Intracranial injuries, unspecified
#
#                                       Part of Body Title  \
# 0                                           Lower leg(s)
# 1                                         Leg(s), n.e.c.
# 2                                        Nonclassifiable
# 3                                    Leg(s), unspecified
# 4                       Finger(s), fingernail(s), n.e.c.
# 5                                               Elbow(s)
# 6                                           Fingertip(s)
# 7                                        Nonclassifiable
# 8                                        Nonclassifiable
# 9                                           Fingertip(s)
# 10                               Upper and lower limb(s)
# 11                                          BODY SYSTEMS
# 12                                                Hip(s)
# 13                           Multiple body parts, n.e.c.
# 14                                          Fingertip(s)
# 15                      Finger(s), fingernail(s), n.e.c.
# 16                                       Nonclassifiable
# 17                      Finger(s), fingernail(s), n.e.c.
# 18                                          Fingertip(s)
# 19                              Foot (feet), unspecified
# 20                                   Arm(s), unspecified
# 21                                              Wrist(s)
# 22                      Finger(s), fingernail(s), n.e.c.
# 23                           Multiple body parts, n.e.c.
# 24                      Finger(s), fingernail(s), n.e.c.
# 25                      Finger(s), fingernail(s), n.e.c.
# 26       Back, including spine, spinal cord, unspecified
# 27                                            Forearm(s)
# 28                      Ankle(s) and leg(s), unspecified
# 29     Neck, except internal location of diseases or ...
# ...                                                  ...
# 31268                                         Forearm(s)
# 31269  Chest, except internal location of diseases or...
# 31270                            Multiple face locations
# 31271                                           Ankle(s)
# 31272                                Toes(s), toenail(s)
# 31273                           Foot (feet), unspecified
# 31274                         Pelvic region, unspecified
# 31275                 Foot(feet) and leg(s), unspecified
# 31276                                              Brain
# 31277                                             Hip(s)
# 31278                                           Elbow(s)
# 31279                                  Face, unspecified
# 31280                                             Hip(s)
# 31281                   Finger(s), fingernail(s), n.e.c.
# 31282                                             Hip(s)
# 31283                                    Nonclassifiable
# 31284                                       Fingertip(s)
# 31285                        Multiple body parts, n.e.c.
# 31286              Finger(s), fingernail(s), unspecified
# 31287                                       Fingertip(s)
# 31288                                             Pelvis
# 31289                   Finger(s), fingernail(s), n.e.c.
# 31290                                              Brain
# 31291                        Multiple body parts, n.e.c.
# 31292                                       Fingertip(s)
# 31293                                  Head, unspecified
# 31294  Abdomen, except internal location of diseases ...
# 31295                                           Ankle(s)
# 31296                                       Fingertip(s)
# 31297                                              Brain
#
#                                               EventTitle  \
# 0      Injured by physical contact with person while ...
# 1                  Ignition of vapors, gases, or liquids
# 2             Other fall to lower level less than 6 feet
# 3      Caught in or compressed by equipment or object...
# 4      Caught in running equipment or machinery durin...
# 5                    Fall on same level due to slipping
# 6      Caught in running equipment or machinery durin...
# 7                                        Nonclassifiable
# 8             Struck by object or equipment, unspecified
# 9      Injured by slipping or swinging object held by...
# 10     Struck by powered vehicle-nontransport, unspec...
# 11     Indirect exposure to electricity, 220 volts or...
# 12       Fall on same level due to tripping, unspecified
# 13     Struck by object or equipment dropped by other...
# 14     Caught in running equipment or machinery durin...
# 15       Contact with objects and equipment, unspecified
# 16     Pedestrian struck by vehicle in nonroadway are...
# 17     Struck against moving part of machinery or equ...
# 18     Struck against moving part of machinery or equ...
# 19                                    Stepped on object
# 20                Other fall to lower level 6 to 10 feet
# 21     Fall on same level due to tripping on uneven s...
# 22       Contact with objects and equipment, unspecified
# 23     Struck by object falling from vehicle or machi...
# 24     Struck by swinging or slipping object, other t...
# 25     Compressed or pinched by shifting objects or e...
# 26               Other jump to lower level 26 to 30 feet
# 27     Caught in running equipment or machinery durin...
# 28                 Roadway noncollision incident, n.e.c.
# 29                         Strangulation by other person
# ...                                                  ...
# 31268  Caught in running equipment or machinery durin...
# 31269  Caught in running equipment or machinery durin...
# 31270                 Hitting, kicking, beating, shoving
# 31271                                    Nonclassifiable
# 31272       Struck by object or equipment rolling freely
# 31273  Part of occupants body caught between vehicle...
# 31274  Fall or jump curtailed by personal fall arrest...
# 31275             Contact with hot objects or substances
# 31276             Other fall to lower level, unspecified
# 31277                Fall on same level due to slipping
# 31278                Fall on same level due to slipping
# 31279                                  Fire, unspecified
# 31280         Other fall to lower level less than 6 feet
# 31281  Struck against moving part of machinery or equ...
# 31282    Fall on same level due to tripping, unspecified
# 31283             Other fall to lower level, unspecified
# 31284  Caught in running equipment or machinery durin...
# 31285              Ignition of vapors, gases, or liquids
# 31286  Compressed or pinched by shifting objects or e...
# 31287  Compressed or pinched by shifting objects or e...
# 31288             Other fall to lower level, unspecified
# 31289  Caught in running equipment or machinery durin...
# 31290                Fall on same level due to slipping
# 31291  Struck by swinging or slipping object, other t...
# 31292  Caught in running equipment or machinery durin...
# 31293                Fall on same level due to slipping
# 31294                                    Nonclassifiable
# 31295  Struck by powered vehicle-nontransport, unspec...
# 31296      Struck by falling object or equipment, n.e.c.
# 31297                        Fall on same level, n.e.c.
#
#                                              SourceTitle  EventYear  \
# 0                                              Co-worker       2015
# 1                     Welding, cutting, and blow torches       2015
# 2                    Semi, tractor-trailer, tanker truck       2015
# 3                                    Pallet jack-powered       2015
# 4      Metal, woodworking, and special material machi...       2015
# 5         Floors, walkways, ground surfaces, unspecified       2015
# 6                 Special process machinery, unspecified       2015
# 7                                        Nonclassifiable       2015
# 8                                     Tires, except bike       2015
# 9                          Knives, unspecified or n.e.c.       2015
# 10                     Excavating machinery, unspecified       2015
# 11               Packaging, wrapping, bundling machinery       2015
# 12        Floors, walkways, ground surfaces, unspecified       2015
# 13                           Structural elements, n.e.c.       2015
# 14                      Gymnasium and exercise equipment       2015
# 15                                  Butchering machinery       2015
# 16                                            Automobile       2015
# 17                               Climate control systems       2015
# 18                        Saws-powered, except chainsaws       2015
# 19             Nails, brads, tacks, nuts, bolts, washers       2015
# 20                                  Ladders, unspecified       2015
# 21                                   Ground irregularity       2015
# 22     Extruding, injecting, forming, molding machine...       2015
# 23                   Bars, rods, reinforcing bar (rebar)       2015
# 24               Packaging, wrapping, bundling machinery       2015
# 25                    Cart, dolly, hand truck-nonpowered       2015
# 26                                     Extension ladders       2015
# 27                        Conveyors-powered, unspecified       2015
# 28        Forklift, order picker, platform truck-powered       2015
# 29                                              Patient        2015
# ...                                                  ...        ...
# 31268                 Boring, routing, notching machines       2018
# 31269                    Oil drilling rigs and machinery       2018
# 31270  Co-worker or work associate of injured or ill ...       2018
# 31271                                    Nonclassifiable       2018
# 31272           Metal sheets, ingots, bars-nonstructural       2018
# 31273  Industrial vehicle, material hauling and trans...       2018
# 31274                                    Nonclassifiable       2018
# 31275                                              Water       2018
# 31276                         Stairs, steps, unspecified       2018
# 31277                                      Floor, n.e.c.       2018
# 31278                           Parking lot, unspecified       2018
# 31279                                    Nonclassifiable       2018
# 31280                                  Machine platforms       2018
# 31281           Sawing machinery-stationary, unspecified       2018
# 31282                                      Floor, n.e.c.       2018
# 31283                               Ladders, unspecified       2018
# 31284                Garbage, recycling, or refuse truck       2018
# 31285                                    Nonclassifiable       2018
# 31286                                     Bundles, bales       2018
# 31287                      Material and personnel hoists       2018
# 31288   Aerial lifts, scissor lifts-except truck-mounted       2018
# 31289                                           Chippers       2018
# 31290                                  Parking lot-paved       2018
# 31291                               Roof trusses, joists       2018
# 31292                                     Conveyors-belt       2018
# 31293     Floors, walkways, ground surfaces, unspecified       2018
# 31294                                    Nonclassifiable       2018
# 31295                             Pallet jack-nonpowered       2018
# 31296  Material and personnel handling machinery, uns...       2018
# 31297     Floors, walkways, ground surfaces, unspecified       2018
#
#       EventMonth  EventDay EventDayofWeek  Have_Address2  Have_SecondarySource
# 0            Jan         1            Thu              0                     1
# 1            Jan         1            Thu              0                     0
# 2            Jan         1            Thu              0                     1
# 3            Jan         1            Thu              0                     1
# 4            Jan         1            Thu              0                     0
# 5            Jan         1            Thu              0                     0
# 6            Jan         1            Thu              0                     0
# 7            Jan         2            Fri              0                     0
# 8            Jan         2            Fri              0                     0
# 9            Jan         2            Fri              0                     0
# 10           Jan         2            Fri              0                     0
# 11           Jan         2            Fri              0                     1
# 12           Jan         2            Fri              0                     0
# 13           Jan         2            Fri              0                     0
# 14           Jan         2            Fri              0                     0
# 15           Jan         2            Fri              0                     0
# 16           Jan         2            Fri              0                     0
# 17           Jan         2            Fri              0                     0
# 18           Jan         2            Fri              0                     0
# 19           Jan         2            Fri              1                     0
# 20           Jan         2            Fri              0                     0
# 21           Jan         2            Fri              0                     1
# 22           Jan         3            Sat              0                     0
# 23           Jan         3            Sat              0                     0
# 24           Jan         3            Sat              0                     0
# 25           Jan         3            Sat              0                     0
# 26           Jan         3            Sat              0                     1
# 27           Jan         3            Sat              0                     0
# 28           Jan         3            Sat              0                     0
# 29           Jan         4            Sun              0                     0
# ...          ...       ...            ...            ...                   ...
# 31268        Jan        31            Wed              0                     0
# 31269        Jan        31            Wed              1                     0
# 31270        Jan        31            Wed              0                     0
# 31271        Jan        31            Wed              0                     0
# 31272        Jan        31            Wed              0                     0
# 31273        Jan        31            Wed              0                     1
# 31274        Jan        31            Wed              0                     0
# 31275        Jan        31            Wed              0                     0
# 31276        Jan        31            Wed              1                     0
# 31277        Jan        31            Wed              0                     0
# 31278        Jan        31            Wed              0                     1
# 31279        Jan        31            Wed              0                     1
# 31280        Jan        31            Wed              0                     0
# 31281        Jan        31            Wed              0                     0
# 31282        Jan        31            Wed              1                     0
# 31283        Jan        31            Wed              0                     0
# 31284        Jan        31            Wed              0                     0
# 31285        Jan        31            Wed              0                     0
# 31286        Jan        31            Wed              1                     0
# 31287        Jan        31            Wed              0                     1
# 31288        Jan        31            Wed              0                     1
# 31289        Jan        31            Wed              0                     0
# 31290        Jan        31            Wed              0                     1
# 31291        Jan        31            Wed              0                     1
# 31292        Jan        31            Wed              0                     0
# 31293        Jan        31            Wed              0                     1
# 31294        Jan        31            Wed              0                     0
# 31295        Jan        31            Wed              0                     0
# 31296        Jan        31            Wed              0                     0
# 31297        Jan        31            Wed              0                     0
#
# [31076 rows x 17 columns]

# %%
idx = list()
target = list()
for index, row in df.iterrows():
    
    if row['Hospitalized'] == 1:
        idx.append(index + 1)
        target.append('Hospitalized') 
        
    if row['Amputation'] == 1:
        idx.append(index + 1)
        target.append('Amputated') 
        
    if row['Have_SecondarySource'] == 1:
        idx.append(index + 1)
        target.append('Have Secondary Source') 
   
    idx.append(index + 1)
    target.append(row['Part of Body Title'])
    
    idx.append(index + 1)
    target.append(row['EventTitle'])
    
    idx.append(index + 1)
    target.append(row['SourceTitle'])
    
df_formatted = pd.DataFrame({'id':idx, 'target': target})

# %%
df.to_csv('severeinjury_cleaned.csv')
df_formatted.to_csv('severeinjury_formatted.csv', index=False)
